# %% [markdown]
# # 1. Hash Map / Dictionary
# Structure cle -> valeur pour acces O(1) en moyenne.
#
# Cas d'usage typiques :
# - Compter des frequences
# - Stocker des indices / complements deja vus
# - Grouper des elements par cle

# %%
from collections import Counter, defaultdict

# %%
def two_sum(nums: list[int], target: int) -> list[int]:
    # TODO (LeetCode 1, O(n) temps / O(n) espace) : retourne les indices [i, j] de deux
    # nombres de nums dont la somme vaut target, en utilisant un dict pour retenir
    # les complements deja vus. Retourne [] si aucune paire ne convient.
    pass

# %%
def group_anagrams(words: list[str]) -> list[list[str]]:
    # TODO (LeetCode 49, O(n * k log k)) : regroupe les mots qui sont des anagrammes
    # entre eux (meme lettres). Utilise un dict dont la cle est une signature
    # (ex: tuple des lettres triees) et retourne la liste des groupes.
    pass

# %%
def max_subarray_sum_zero(nums: list[int]) -> int:
    # TODO (O(n)) : retourne la longueur du plus long sous-tableau contigu dont la
    # somme vaut 0. Utilise un dict prefix_sum -> premier index ou cette somme a ete vue.
    pass

# %%
def top_k_frequent(nums: list[int], k: int) -> list[int]:
    # TODO : retourne les k elements les plus frequents de nums, du plus au moins
    # frequent (utilise Counter pour compter les occurrences).
    pass

# %%
def is_isomorphic(s: str, t: str) -> bool:
    # TODO (LeetCode 205) : retourne True si s et t sont isomorphiques, c'est-a-dire
    # s'il existe une correspondance bijective caractere <-> caractere entre les deux
    # chaines (utilise deux dicts pour verifier la correspondance dans les deux sens).
    pass

# %% [markdown]
# ## Tests
#
# Execute la cellule ci-dessous : elle valide toutes les fonctions avec des assertions. Un message `OK` confirme que tout passe.

# %%
def run_tests() -> None:
    assert two_sum([2, 7, 11, 15], 9) == [0, 1]
    assert sorted(group_anagrams(["eat", "tea", "tan", "ate", "nat", "bat"])) == sorted(
        [["eat", "tea", "ate"], ["tan", "nat"], ["bat"]]
    )
    assert max_subarray_sum_zero([15, -2, 2, -8, 1, 7, 10, 23]) == 5
    assert top_k_frequent([1, 1, 1, 2, 2, 3], 2) == [1, 2]
    assert is_isomorphic("egg", "add") is True
    assert is_isomorphic("foo", "bar") is False
    print("Tous les tests hash_map OK")

run_tests()
