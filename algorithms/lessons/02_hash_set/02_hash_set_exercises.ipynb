# %% [markdown]
# # 2. Hash Set
# Ensemble de valeurs uniques avec test d'appartenance O(1) en moyenne.
#
# Cas d'usage typiques :
# - Detecter les doublons
# - Trouver l'intersection / union
# - Parcours avec memoire des elements deja vus

# %%
def contains_duplicate(nums: list[int]) -> bool:
    # TODO (LeetCode 217, O(n) temps / O(n) espace) : retourne True si une valeur
    # apparait au moins deux fois dans nums, en utilisant un set pour memoriser les
    # valeurs deja vues.
    pass

# %%
def first_unique_char(s: str) -> int:
    # TODO : retourne l'index du premier caractere de s qui n'apparait qu'une seule
    # fois. Utilise deux sets (vus / repetes) pour identifier les caracteres uniques,
    # puis retourne -1 si aucun caractere unique n'existe.
    pass

# %%
def intersection(nums1: list[int], nums2: list[int]) -> list[int]:
    # TODO (LeetCode 349) : retourne l'intersection (sans doublons) de nums1 et nums2,
    # en convertissant nums1 en set pour un test d'appartenance O(1).
    pass

# %%
def longest_consecutive(nums: list[int]) -> int:
    # TODO (LeetCode 128, O(n)) : retourne la longueur de la plus longue sequence
    # d'entiers consecutifs presente dans nums. Utilise un set et ne demarre le
    # comptage d'une sequence que si num - 1 n'est pas dans le set.
    pass

# %%
def _sum_squares(n: int) -> int:
    # TODO : retourne la somme des carres des chiffres de n (ex: 19 -> 1**2 + 9**2 = 82).
    pass

# %%
def is_happy(n: int) -> bool:
    # TODO (LeetCode 202) : retourne True si n est un "happy number", c'est-a-dire si
    # en repetant _sum_squares on finit par atteindre 1. Utilise un set pour detecter
    # un cycle (si une somme deja vue revient, ce n'est pas un happy number).
    pass

# %% [markdown]
# ## Tests
#
# Execute la cellule ci-dessous : elle valide toutes les fonctions avec des assertions. Un message `OK` confirme que tout passe.

# %%
def run_tests() -> None:
    assert contains_duplicate([1, 2, 3, 1]) is True
    assert contains_duplicate([1, 2, 3, 4]) is False
    assert first_unique_char("leetcode") == 0
    assert first_unique_char("aabb") == -1
    assert sorted(intersection([1, 2, 2, 1], [2, 2])) == [2]
    assert longest_consecutive([100, 4, 200, 1, 3, 2]) == 4
    assert is_happy(19) is True
    assert is_happy(2) is False
    print("Tous les tests hash_set OK")

run_tests()
