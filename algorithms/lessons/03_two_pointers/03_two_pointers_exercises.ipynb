# %% [markdown]
# # 3. Two Pointers (deux pointeurs)
# Deux indices qui avancent selon une regle. Souvent sur un tableau trie.
#
# Variantes :
# - Opposes (left/right)
# - Meme direction (slow/fast)

# %%
def is_palindrome(s: str) -> bool:
    # TODO (LeetCode 125, O(n)) : retourne True si s est un palindrome en ignorant les
    # caracteres non-alphanumeriques et la casse. Utilise deux pointeurs left/right qui
    # avancent l'un vers l'autre.
    pass

# %%
def two_sum_sorted(numbers: list[int], target: int) -> list[int]:
    # TODO (LeetCode 167, O(n)) : numbers est trie. Retourne les indices (1-indexes)
    # [i, j] de deux nombres dont la somme vaut target, avec deux pointeurs
    # opposes qui se rapprochent selon que la somme courante est trop petite/grande.
    pass

# %%
def remove_duplicates(nums: list[int]) -> int:
    # TODO (LeetCode 26, O(n)) : nums est trie. Retire les doublons in-place (en
    # ecrivant a l'avant du tableau via un pointeur write) et retourne le nombre
    # d'elements uniques restants.
    pass

# %%
def max_area(height: list[int]) -> int:
    # TODO (LeetCode 11, O(n)) : retourne l'aire maximale d'eau que peut contenir le
    # container forme par deux lignes de height (largeur * hauteur min des deux
    # bords). Utilise deux pointeurs opposes en deplacant toujours le plus petit bord.
    pass

# %%
class ListNode:
    def __init__(self, val: int = 0, next: "ListNode | None" = None):
        self.val = val
        self.next = next

# %%
def has_cycle(head: ListNode | None) -> bool:
    # TODO (detection de cycle de Floyd, slow/fast pointers) : retourne True si la
    # linked list a partir de head contient un cycle. Avance slow d'un pas et fast de
    # deux pas ; s'ils se rencontrent, il y a un cycle.
    pass

# %% [markdown]
# ## Tests
#
# Execute la cellule ci-dessous : elle valide toutes les fonctions avec des assertions. Un message `OK` confirme que tout passe.

# %%
def run_tests() -> None:
    assert is_palindrome("A man, a plan, a canal: Panama") is True
    assert two_sum_sorted([2, 7, 11, 15], 9) == [1, 2]
    nums = [0, 0, 1, 1, 1, 2, 2, 3, 3, 4]
    assert remove_duplicates(nums) == 5
    assert nums[:5] == [0, 1, 2, 3, 4]
    assert max_area([1, 8, 6, 2, 5, 4, 8, 3, 7]) == 49

    node3 = ListNode(3)
    node2 = ListNode(2, node3)
    node1 = ListNode(1, node2)
    node3.next = node1
    assert has_cycle(node1) is True
    assert has_cycle(ListNode(1)) is False
    print("Tous les tests two_pointers OK")

run_tests()
