# %% [markdown]
# # 4. Sliding Window (fenetre glissante)
# Maintenir une fenetre [left, right] et l'ajuster selon une contrainte.
#
# Cas d'usage :
# - Sous-chaine / sous-tableau de longueur fixe ou variable
# - Maximum/minimum sur une fenetre

# %%
from collections import Counter, defaultdict

# %%
def max_subarray_len_sum_at_most(nums: list[int], k: int) -> int:
    # TODO (O(n)) : retourne la longueur du plus long sous-tableau contigu dont la
    # somme est <= k. Utilise une fenetre glissante [left, right] : agrandis right,
    # et retrecis left tant que la somme de la fenetre depasse k.
    pass

# %%
def min_subarray_len(target: int, nums: list[int]) -> int:
    # TODO (LeetCode 209, O(n)) : retourne la longueur minimale d'un sous-tableau
    # contigu dont la somme est >= target (0 si aucun n'existe). Fenetre glissante :
    # agrandis right, retrecis left tant que la somme reste >= target.
    pass

# %%
def length_of_longest_substring(s: str) -> int:
    # TODO (LeetCode 3, O(n)) : retourne la longueur de la plus longue sous-chaine
    # sans caractere repete. Utilise un dict last_seen (caractere -> dernier index) et
    # deplace left juste apres la derniere occurrence d'un caractere repete.
    pass

# %%
def find_anagrams(s: str, p: str) -> list[int]:
    # TODO (LeetCode 438, O(n)) : retourne tous les index de depart dans s des
    # sous-chaines de longueur len(p) qui sont des anagrammes de p. Utilise une
    # fenetre glissante de taille fixe avec des compteurs (Counter/dict) pour need et
    # window.
    pass

# %%
def max_sum_subarray_k(nums: list[int], k: int) -> int:
    # TODO (O(n)) : retourne la somme maximale d'un sous-tableau de k elements
    # consecutifs. Fenetre de taille fixe : calcule la somme initiale des k premiers
    # elements puis fais-la glisser en ajoutant/retirant un element a chaque pas.
    pass

# %% [markdown]
# ## Tests
#
# Execute la cellule ci-dessous : elle valide toutes les fonctions avec des assertions. Un message `OK` confirme que tout passe.

# %%
def run_tests() -> None:
    assert max_subarray_len_sum_at_most([1, 2, 1, 0, 1, 1, 0], 4) == 5
    assert min_subarray_len(7, [2, 3, 1, 2, 4, 3]) == 2
    assert length_of_longest_substring("abcabcbb") == 3
    assert find_anagrams("cbaebabacd", "abc") == [0, 6]
    assert max_sum_subarray_k([2, 1, 5, 1, 3, 2], 3) == 9
    print("Tous les tests sliding_window OK")

run_tests()
