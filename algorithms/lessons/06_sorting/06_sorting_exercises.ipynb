# %% [markdown]
# # 6. Sorting (tri)
# Connaitre les tris courants et quand les utiliser.
#
# Complexites :
# - QuickSort / MergeSort : O(n log n)
# - Counting sort : O(n + k) si valeurs bornees
# - Timsort (Python sorted) : O(n log n), stable

# %%
from collections import Counter

# %%
def sort_by_absolute_value(nums: list[int]) -> list[int]:
    # TODO : Exemple 1 : tri custom avec key -- retourne nums tries par valeur absolue croissante (utilise sorted() avec key=abs)
    pass

# %%
def sort_intervals(intervals: list[list[int]]) -> list[list[int]]:
    # TODO : tri custom avec key -- retourne intervals tries par borne de debut puis de fin
    pass

# %%
def merge_intervals(intervals: list[list[int]]) -> list[list[int]]:
    # TODO : Exemple 2 : Merge Intervals | LeetCode 56 | O(n log n) -- trie les intervalles par debut puis fusionne ceux qui se chevauchent
    pass

# %%
def find_kth_largest(nums: list[int], k: int) -> int:
    # TODO : Exemple 3 : Kth Largest Element | LeetCode 215 | O(n log n) -- retourne le k-ieme plus grand element (tri simple)
    pass

# %%
def find_kth_largest_quickselect(nums: list[int], k: int) -> int:
    # TODO : Kth Largest Element via quickselect | LeetCode 215 | O(n) en moyenne -- utilise une partition type quicksort pour trouver le k-ieme plus grand sans trier entierement
    pass

# %%
def can_attend_meetings(intervals: list[list[int]]) -> bool:
    # TODO : Exemple 4 : Meeting Rooms -- detecter conflit | LeetCode 252 -- trie par debut puis verifie qu'aucun intervalle ne commence avant la fin du precedent
    pass

# %%
def frequency_sort(nums: list[int]) -> list[int]:
    # TODO : Exemple 5 : tri par frequence puis valeur | LeetCode 1636 -- trie nums par frequence croissante, puis par valeur croissante en cas d'egalite
    pass

# %%
def counting_sort(nums: list[int], max_value: int) -> list[int]:
    # TODO : Exemple 6 : Counting sort (valeurs non negatives petites) | O(n + k) -- compte les occurrences de chaque valeur de 0 a max_value puis reconstruit la liste triee
    pass

# %% [markdown]
# ## Tests
#
# Execute la cellule ci-dessous : elle valide toutes les fonctions avec des assertions. Un message `OK` confirme que tout passe.

# %%
def run_tests() -> None:
    assert sort_by_absolute_value([-3, 1, -2, 4]) == [1, -2, -3, 4]
    assert merge_intervals([[1, 3], [2, 6], [8, 10], [15, 18]]) == [[1, 6], [8, 10], [15, 18]]
    assert find_kth_largest([3, 2, 1, 5, 6, 4], 2) == 5
    assert find_kth_largest_quickselect([3, 2, 3, 1, 2, 4, 5, 5, 6], 4) == 4
    assert can_attend_meetings([[0, 30], [5, 10], [15, 20]]) is False
    assert frequency_sort([2, 3, 1, 3, 2, 2, 2]) == [1, 3, 3, 2, 2, 2, 2]
    assert counting_sort([4, 2, 2, 8, 3, 3], 8) == [2, 2, 3, 3, 4, 8]
    print("Tous les tests sorting OK")

run_tests()
