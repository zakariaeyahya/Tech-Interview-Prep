# %% [markdown]
# # 7. Binary Search (recherche dichotomique)
# Recherche O(log n) sur un espace trie ou monotone.
#
# Pattern :
# - left, right = bornes
# - while left <= right (ou left < right selon variante)
# - mid = left + (right - left) // 2

# %%
def binary_search(nums: list[int], target: int) -> int:
    # TODO : Exemple 1 : recherche binaire classique | O(log n) -- retourne l'index de target dans nums trie, ou -1 si absent
    pass

# %%
def search_range(nums: list[int], target: int) -> list[int]:
    # TODO : Exemple 2 : First / Last Position | LeetCode 34 | O(log n) -- retourne [premier_index, dernier_index] de target dans nums trie (deux recherches binaires bornees), [-1, -1] si absent
    pass

# %%
def search_rotated(nums: list[int], target: int) -> int:
    # TODO : Exemple 3 : Search in Rotated Sorted Array | LeetCode 33 | O(log n) -- retourne l'index de target dans un tableau trie puis pivote, ou -1 si absent
    pass

# %%
def min_eating_speed(piles: list[int], h: int) -> int:
    # TODO : Exemple 4 : recherche binaire sur la reponse | LeetCode 875 (Koko eating bananas) | O(n log max(piles)) -- retourne la vitesse minimale pour manger toutes les piles en au plus h heures
    pass

# %%
def my_sqrt(x: int) -> int:
    # TODO : Exemple 5 : sqrt(x) entier | LeetCode 69 | O(log x) -- retourne la partie entiere de la racine carree de x sans utiliser **0.5
    pass

# %%
def lower_bound(nums: list[int], target: int) -> int:
    # TODO : Exemple 6 : lower bound (premier index >= target) | O(log n) -- retourne le premier index ou target pourrait etre insere pour garder nums trie
    pass

# %% [markdown]
# ## Tests
#
# Execute la cellule ci-dessous : elle valide toutes les fonctions avec des assertions. Un message `OK` confirme que tout passe.

# %%
def run_tests() -> None:
    nums = [1, 3, 5, 7, 9, 11]
    assert binary_search(nums, 7) == 3
    assert binary_search(nums, 6) == -1
    assert search_range([5, 7, 7, 8, 8, 10], 8) == [3, 4]
    assert search_rotated([4, 5, 6, 7, 0, 1, 2], 0) == 4
    assert min_eating_speed([3, 6, 7, 11], 8) == 4
    assert my_sqrt(8) == 2
    assert lower_bound([1, 2, 2, 4], 2) == 1
    print("Tous les tests binary_search OK")

run_tests()
