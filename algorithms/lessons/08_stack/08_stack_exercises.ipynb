# %% [markdown]
# # 8. Stack (pile LIFO)
# Last In, First Out — utile pour parentheses, parsing, DFS iteratif.
#
# En Python : list avec append() et pop()

# %%
def is_valid_parentheses(s: str) -> bool:
    # TODO : Exemple 1 : Parentheses valides | LeetCode 20 | O(n) -- retourne True si les parentheses/crochets/accolades de s sont bien appariees et imbriquees (utilise une pile)
    pass

# %%
def eval_rpn(tokens: list[str]) -> int:
    # TODO : Exemple 2 : Evaluate Reverse Polish Notation | LeetCode 150 -- evalue une expression en notation polonaise inversee a l'aide d'une pile (empile les nombres, depile deux operandes a chaque operateur)
    pass

# %%
class MinStack:
    def __init__(self):
        self.stack: list[int] = []
        self.min_stack: list[int] = []

    def push(self, val: int) -> None:
        # TODO : empile val sur self.stack, et sur self.min_stack seulement si c'est une nouvelle valeur minimale (<=)
        pass

    def pop(self) -> None:
        # TODO : depile le sommet de self.stack ; si c'etait aussi le minimum courant, depile aussi self.min_stack
        pass

    def top(self) -> int:
        # TODO : retourne l'element au sommet de self.stack sans le retirer
        pass

    def get_min(self) -> int:
        # TODO : retourne le minimum courant de la pile en O(1) (sommet de self.min_stack)
        pass

# %%
def daily_temperatures(temperatures: list[int]) -> list[int]:
    # TODO : Exemple 4 : Daily Temperatures | LeetCode 739 | O(n) -- pour chaque jour, retourne le nombre de jours a attendre avant une temperature plus chaude (0 si aucune), via une pile decroissante d'index
    pass

# %%
def simplify_path(path: str) -> str:
    # TODO : Exemple 5 : simplifier un chemin Unix | LeetCode 71 -- normalise un chemin absolu en resolvant '.' (dossier courant) et '..' (remonte d'un niveau) a l'aide d'une pile de composants
    pass

# %% [markdown]
# ## Tests
#
# Execute la cellule ci-dessous : elle valide toutes les fonctions avec des assertions. Un message `OK` confirme que tout passe.

# %%
def run_tests() -> None:
    assert is_valid_parentheses("()[]{}") is True
    assert is_valid_parentheses("(]") is False
    assert eval_rpn(["2", "1", "+", "3", "*"]) == 9
    assert eval_rpn(["4", "13", "5", "/", "+"]) == 6

    ms = MinStack()
    ms.push(-2)
    ms.push(0)
    ms.push(-3)
    assert ms.get_min() == -3
    ms.pop()
    assert ms.top() == 0
    assert ms.get_min() == -2

    assert daily_temperatures([73, 74, 75, 71, 69, 72, 76, 73]) == [1, 1, 4, 2, 1, 1, 0, 0]
    assert simplify_path("/home//foo/") == "/home/foo"
    print("Tous les tests stack OK")

run_tests()
