# %% [markdown]
# # 9. Monotonic Stack (pile monotone)
# Pile ou les elements sont toujours croissants ou decroissants.
#
# Cas d'usage :
# - Prochain element plus grand/petit
# - Largest rectangle in histogram
# - Trapping rain water

# %%
def next_greater_element(nums1: list[int], nums2: list[int]) -> list[int]:
    # TODO : Exemple 1 : Next Greater Element | LeetCode 496 | O(n) -- pour chaque element de nums1 (sous-ensemble de nums2), trouve son prochain element plus grand a droite dans nums2 (via une pile decroissante), -1 si aucun
    pass

# %%
def daily_temperatures(temperatures: list[int]) -> list[int]:
    # TODO : Exemple 2 : Daily Temperatures (pile decroissante) | LeetCode 739 | O(n) -- pour chaque jour, retourne le nombre de jours a attendre avant une temperature plus chaude, 0 si aucune
    pass

# %%
def largest_rectangle_area(heights: list[int]) -> int:
    # TODO : Exemple 3 : Largest Rectangle in Histogram | LeetCode 84 | O(n) -- retourne l'aire du plus grand rectangle possible dans un histogramme, via une pile croissante d'index
    pass

# %%
def trap(height: list[int]) -> int:
    # TODO : Exemple 4 : Trapping Rain Water | LeetCode 42 | O(n) avec pile monotone -- calcule le volume d'eau retenue entre les barres d'un histogramme
    pass

# %%
def sum_subarray_mins(arr: list[int]) -> int:
    # TODO : Exemple 5 : Sum of Subarray Minimums | LeetCode 907 | O(n) -- calcule la somme (modulo 10**9+7) des minimums de tous les sous-tableaux contigus de arr, en trouvant pour chaque element la portee ou il est le minimum (prev_less/next_less via pile)
    pass

# %% [markdown]
# ## Tests
#
# Execute la cellule ci-dessous : elle valide toutes les fonctions avec des assertions. Un message `OK` confirme que tout passe.

# %%
def run_tests() -> None:
    assert next_greater_element([4, 1, 2], [1, 3, 4, 2]) == [-1, 3, -1]
    assert daily_temperatures([73, 74, 75, 71, 69, 72, 76, 73]) == [1, 1, 4, 2, 1, 1, 0, 0]
    assert largest_rectangle_area([2, 1, 5, 6, 2, 3]) == 10
    assert trap([0, 1, 0, 2, 1, 0, 1, 3, 2, 1, 2, 1]) == 6
    assert sum_subarray_mins([3, 1, 2, 4]) == 17
    print("Tous les tests monotonic_stack OK")

run_tests()
