# %% [markdown]
# # 11. Linked List (liste chainee)
# Noeuds avec .val et .next — operations fondamentales pour entretiens.
#
# Attention aux edge cases :
# - liste vide
# - un seul noeud
# - modifier head / tail

# %%
class ListNode:
    def __init__(self, val: int = 0, next: "ListNode | None" = None):
        self.val = val
        self.next = next

# %%
def build_list(values: list[int]) -> ListNode | None:
    dummy = ListNode()
    current = dummy
    for val in values:
        current.next = ListNode(val)
        current = current.next
    return dummy.next

# %%
def list_to_array(head: ListNode | None) -> list[int]:
    result = []
    while head:
        result.append(head.val)
        head = head.next
    return result

# %%
def reverse_list(head: ListNode | None) -> ListNode | None:
    # TODO : Exemple 1 (LeetCode 206) - inverse la liste chainee et retourne la nouvelle tete. O(n)
    pass

# %%
def merge_two_lists(l1: ListNode | None, l2: ListNode | None) -> ListNode | None:
    # TODO : Exemple 2 (LeetCode 21) - fusionne deux listes triees en une seule liste triee
    pass

# %%
def has_cycle(head: ListNode | None) -> bool:
    # TODO : Exemple 3 (LeetCode 141) - detecte un cycle avec Floyd (slow/fast). O(n)
    pass

# %%
def middle_node(head: ListNode | None) -> ListNode | None:
    # TODO : Exemple 4 (LeetCode 876) - retourne le noeud du milieu (slow/fast). O(n)
    pass

# %%
def remove_nth_from_end(head: ListNode | None, n: int) -> ListNode | None:
    # TODO : Exemple 5 (LeetCode 19) - supprime le n-ieme noeud en partant de la fin, deux pointeurs + dummy head
    pass

# %%
def reorder_list(head: ListNode | None) -> None:
    # TODO : Exemple 6 (LeetCode 143) - reordonne la liste en place L0->Ln->L1->Ln-1->... (in-place, retourne None)
    pass

# %%
def is_palindrome_list(head: ListNode | None) -> bool:
    # TODO : Exemple 7 (LeetCode 234) - determine si la liste chainee est un palindrome
    pass

# %% [markdown]
# ## Tests
#
# Execute la cellule ci-dessous : elle valide toutes les fonctions avec des assertions. Un message `OK` confirme que tout passe.

# %%
def run_tests() -> None:
    assert list_to_array(reverse_list(build_list([1, 2, 3, 4, 5]))) == [5, 4, 3, 2, 1]
    assert list_to_array(merge_two_lists(build_list([1, 2, 4]), build_list([1, 3, 4]))) == [1, 1, 2, 3, 4, 4]

    node3 = ListNode(3)
    node2 = ListNode(2, node3)
    node1 = ListNode(1, node2)
    node3.next = node1
    assert has_cycle(node1) is True

    assert middle_node(build_list([1, 2, 3, 4, 5])).val == 3
    assert list_to_array(remove_nth_from_end(build_list([1, 2, 3, 4, 5]), 2)) == [1, 2, 3, 5]

    head = build_list([1, 2, 3, 4])
    reorder_list(head)
    assert list_to_array(head) == [1, 4, 2, 3]

    assert is_palindrome_list(build_list([1, 2, 2, 1])) is True
    assert is_palindrome_list(build_list([1, 2])) is False
    print("Tous les tests linked_list OK")

run_tests()
