# %% [markdown]
# # 13. Merge Intervals (fusion d'intervalles)
# On trie les intervalles par debut, puis on parcourt : si le courant
# chevauche le dernier fusionne, on etend ; sinon on ajoute un nouvel
# intervalle.
#
# Idee cle : apres tri, deux intervalles se chevauchent ssi
# start_courant <= end_precedent.

# %%
def merge(intervals: list[list[int]]) -> list[list[int]]:
    # TODO : Exemple 1 (LeetCode 56) - trie par debut puis fusionne les intervalles qui se chevauchent. O(n log n)
    pass

# %%
def insert(intervals: list[list[int]], new: list[int]) -> list[list[int]]:
    # TODO : Exemple 2 (LeetCode 57) - insere un intervalle dans une liste triee sans chevauchement et fusionne si besoin. O(n)
    pass

# %%
def interval_intersection(a: list[list[int]], b: list[list[int]]) -> list[list[int]]:
    # TODO : Exemple 3 (LeetCode 986) - intersection de deux listes d'intervalles triees, deux pointeurs. O(n + m)
    pass

# %%
def min_meeting_rooms(intervals: list[list[int]]) -> int:
    # TODO : Exemple 4 (LeetCode 253) - nombre minimal de salles de reunion via balayage debuts/fins tries. O(n log n)
    pass

# %% [markdown]
# ## Tests
#
# Execute la cellule ci-dessous : elle valide toutes les fonctions avec des assertions. Un message `OK` confirme que tout passe.

# %%
def run_tests() -> None:
    assert merge([[1, 3], [2, 6], [8, 10], [15, 18]]) == [[1, 6], [8, 10], [15, 18]]
    assert merge([[1, 4], [4, 5]]) == [[1, 5]]

    assert insert([[1, 3], [6, 9]], [2, 5]) == [[1, 5], [6, 9]]
    assert insert([[1, 2], [3, 5], [6, 7], [8, 10], [12, 16]], [4, 8]) == [
        [1, 2], [3, 10], [12, 16]
    ]

    assert interval_intersection(
        [[0, 2], [5, 10], [13, 23], [24, 25]],
        [[1, 5], [8, 12], [15, 24], [25, 26]],
    ) == [[1, 2], [5, 5], [8, 10], [15, 23], [24, 24], [25, 25]]

    assert min_meeting_rooms([[0, 30], [5, 10], [15, 20]]) == 2
    assert min_meeting_rooms([[7, 10], [2, 4]]) == 1

    print("Tous les tests merge_intervals OK")

run_tests()
