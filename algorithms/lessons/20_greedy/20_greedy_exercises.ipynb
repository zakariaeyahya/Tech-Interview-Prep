# %% [markdown]
# # 20. Greedy (algorithme glouton)
# A chaque etape, on fait le choix localement optimal en esperant qu'il
# mene a l'optimum global. Rapide (souvent O(n log n) avec un tri), mais
# ne marche que si le probleme a la propriete du "choix glouton".
#
# Difference avec la DP : le glouton ne revient jamais en arriere ; il faut
# prouver (ou reconnaitre) que le choix local est sur.

# %%
def can_jump(nums: list[int]) -> bool:
    # TODO : Jump Game (LeetCode 55). nums[i] est le saut max depuis l'indice i.
    # Retourne True si on peut atteindre le dernier indice depuis l'indice 0. O(n).
    pass

# %%
def jump(nums: list[int]) -> int:
    # TODO : Jump Game II (LeetCode 45). Retourne le nombre minimal de sauts pour
    # atteindre le dernier indice (on part de l'indice 0, on suppose que c'est
    # toujours possible). O(n).
    pass

# %%
def erase_overlap_intervals(intervals: list[list[int]]) -> int:
    # TODO : Non-overlapping Intervals (LeetCode 435). Retourne le nombre minimal
    # d'intervalles a retirer pour que les intervalles restants ne se chevauchent
    # plus. O(n log n) (trier par fin d'intervalle).
    pass

# %%
def candy(ratings: list[int]) -> int:
    # TODO : Candy (LeetCode 135). Chaque enfant a une note ratings[i] ; chacun
    # recoit au moins 1 bonbon, et un enfant avec une meilleure note que son
    # voisin doit avoir plus de bonbons que lui. Retourne le nombre total minimal
    # de bonbons (deux passes gauche->droite puis droite->gauche). O(n).
    pass

# %%
def max_profit(prices: list[int]) -> int:
    # TODO : Best Time to Buy and Sell Stock II (LeetCode 122). Transactions
    # multiples autorisees. Retourne le profit maximal total en capturant chaque
    # hausse consecutive du prix. O(n).
    pass

# %% [markdown]
# ## Tests
#
# Execute la cellule ci-dessous : elle valide toutes les fonctions avec des assertions. Un message `OK` confirme que tout passe.

# %%
def run_tests() -> None:
    assert can_jump([2, 3, 1, 1, 4]) is True
    assert can_jump([3, 2, 1, 0, 4]) is False

    assert jump([2, 3, 1, 1, 4]) == 2
    assert jump([2, 3, 0, 1, 4]) == 2

    assert erase_overlap_intervals([[1, 2], [2, 3], [3, 4], [1, 3]]) == 1
    assert erase_overlap_intervals([[1, 2], [1, 2], [1, 2]]) == 2

    assert candy([1, 0, 2]) == 5                # 2 + 1 + 2
    assert candy([1, 2, 2]) == 4                # 1 + 2 + 1

    assert max_profit([7, 1, 5, 3, 6, 4]) == 7  # (5-1) + (6-3)
    assert max_profit([1, 2, 3, 4, 5]) == 4

    print("Tous les tests greedy OK")

run_tests()
