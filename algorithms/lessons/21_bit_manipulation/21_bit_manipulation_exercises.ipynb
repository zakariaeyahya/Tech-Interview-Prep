# %% [markdown]
# # 21. Bit Manipulation (manipulation de bits)
# On travaille directement sur la representation binaire des entiers avec
# les operateurs bit a bit. Souvent la solution O(1) espace la plus rapide.
#
# Operateurs cles :
#   &  ET      |  OU      ^  XOR      ~  NON      <<  >>  decalages
# Astuces :
#   x & 1            -> bit de poids faible (parite)
#   x & (x - 1)      -> efface le bit 1 le plus a droite
#   x ^ x = 0        -> XOR annule les doublons
#   x & (-x)         -> isole le bit 1 le plus a droite

# %%
def single_number(nums: list[int]) -> int:
    # TODO : Single Number (LeetCode 136). Tous les elements apparaissent deux
    # fois sauf un. Retourne cet element unique via XOR (les doublons s'annulent).
    # O(n) temps, O(1) espace.
    pass

# %%
def count_ones(n: int) -> int:
    # TODO : Number of 1 Bits / Hamming weight (LeetCode 191). Retourne le nombre
    # de bits a 1 dans la representation binaire de n, via n &= n - 1 pour effacer
    # le bit 1 le plus a droite a chaque iteration.
    pass

# %%
def is_power_of_two(n: int) -> bool:
    # TODO : Power of Two (LeetCode 231). Retourne True si n est une puissance de
    # 2 (un seul bit a 1), False sinon. O(1).
    pass

# %%
def missing_number(nums: list[int]) -> int:
    # TODO : Missing Number (LeetCode 268). nums contient n valeurs distinctes
    # dans l'intervalle [0, n]. Retourne le nombre manquant via XOR (indices XOR
    # valeurs). O(n).
    pass

# %%
def reverse_bits(n: int) -> int:
    # TODO : Reverse Bits (LeetCode 190). Retourne les bits de l'entier non signe
    # 32 bits n dans l'ordre inverse. O(1) (32 iterations fixes).
    pass

# %%
def counting_bits(n: int) -> list[int]:
    # TODO : Counting Bits (LeetCode 338), DP + bits. Retourne une liste dp de
    # taille n+1 ou dp[i] est le nombre de bits a 1 de i, en reutilisant
    # dp[i] = dp[i >> 1] + (i & 1). O(n).
    pass

# %% [markdown]
# ## Tests
#
# Execute la cellule ci-dessous : elle valide toutes les fonctions avec des assertions. Un message `OK` confirme que tout passe.

# %%
def run_tests() -> None:
    assert single_number([4, 1, 2, 1, 2]) == 4
    assert single_number([2, 2, 1]) == 1

    assert count_ones(0b1011) == 3
    assert count_ones(0) == 0

    assert is_power_of_two(16) is True
    assert is_power_of_two(18) is False
    assert is_power_of_two(1) is True

    assert missing_number([3, 0, 1]) == 2
    assert missing_number([0, 1]) == 2

    assert reverse_bits(0b00000010100101000001111010011100) == 964176192

    assert counting_bits(5) == [0, 1, 1, 2, 1, 2]

    print("Tous les tests bit_manipulation OK")

run_tests()
