# %% [markdown]
# # Exercices -- Chaines de caracteres (strings)
#
# Notebook d'entrainement, a executer sur Google Colab ou Jupyter.
# **Aucune solution n'est fournie** : implemente chaque fonction dans sa cellule,
# puis **execute la cellule de test juste en dessous** (Maj+Entree) pour verifier
# ton implementation. Si tout est correct, le test affiche `OK`. Sinon, une
# `AssertionError` indique quel cas a echoue.
#
# Sommaire :
# 1. Compter les voyelles
# 2. Inverser une chaine
# 3. Palindrome
# 4. Anagramme
# 5. Compression de chaine (RLE)
# 6. Mettre en majuscule chaque mot
# 7. Supprimer les doublons en gardant l'ordre
# 8. Plus longue sous-chaine sans repetition
# 9. Grouper les anagrammes

# %% [markdown]
# ## Exercice 1 -- Compter les voyelles
#
# Ecris `compte_voyelles(s)` qui retourne le nombre de voyelles (`a, e, i, o, u, y`,
# insensible a la casse) dans la chaine `s`.

# %%
def compte_voyelles(s):
    # TODO : retourne le nombre de voyelles (a, e, i, o, u, y), insensible a la casse
    pass

# %%
# Test -- Exercice 1
assert compte_voyelles("algorithme") == 4
assert compte_voyelles("") == 0
assert compte_voyelles("BCDFG") == 0
assert compte_voyelles("AEIOUY") == 6
assert compte_voyelles("Python") == 2
print("OK")

# %% [markdown]
# ## Exercice 2 -- Inverser une chaine
#
# Ecris `inverse(s)` qui retourne la chaine `s` inversee, **sans utiliser** le
# slicing `[::-1]` ni `reversed()` (utilise une boucle ou une recursion).

# %%
def inverse(s):
    # TODO : retourne s inversee sans [::-1] ni reversed()
    pass

# %%
# Test -- Exercice 2
assert inverse("algorithme") == "emhtirogla"
assert inverse("") == ""
assert inverse("a") == "a"
assert inverse("ab") == "ba"
assert inverse("racecar") == "racecar"
print("OK")

# %% [markdown]
# ## Exercice 3 -- Palindrome
#
# Ecris `est_palindrome(s)` qui retourne `True` si `s` se lit pareil dans les
# deux sens, en **ignorant la casse, les espaces et la ponctuation**.

# %%
def est_palindrome(s):
    # TODO : True si s est un palindrome (ignore casse, espaces, ponctuation)
    pass

# %%
# Test -- Exercice 3
assert est_palindrome("radar") == True
assert est_palindrome("Radar") == True
assert est_palindrome("Esope reste ici et se repose") == True
assert est_palindrome("python") == False
assert est_palindrome("") == True
assert est_palindrome("A man, a plan, a canal: Panama") == True
print("OK")

# %% [markdown]
# ## Exercice 4 -- Anagramme
#
# Ecris `sont_anagrammes(a, b)` qui retourne `True` si `a` et `b` contiennent
# exactement les memes lettres (avec les memes occurrences), en ignorant la
# casse et les espaces.

# %%
def sont_anagrammes(a, b):
    # TODO : True si a et b sont anagrammes (ignore casse, espaces)
    pass

# %%
# Test -- Exercice 4
assert sont_anagrammes("ecoute", "coutee") == True
assert sont_anagrammes("listen", "silent") == True
assert sont_anagrammes("Listen", "Silent") == True
assert sont_anagrammes("bonjour", "aurevoir") == False
assert sont_anagrammes("", "") == True
assert sont_anagrammes("abc", "abcd") == False
print("OK")

# %% [markdown]
# ## Exercice 5 -- Compression de chaine (RLE)
#
# Ecris `compresse(s)` qui applique un *Run-Length Encoding* simple :
# `"aaabccccd"` -> `"a3b1c4d1"`. Si la version compressee n'est pas plus courte
# que l'originale, retourne la chaine originale telle quelle.

# %%
def compresse(s):
    # TODO : RLE (ex: "aaabccccd" -> "a3b1c4d1"), retourne s si pas plus court
    pass

# %%
# Test -- Exercice 5
assert compresse("aaabccccd") == "a3b1c4d1"
assert compresse("abcd") == "abcd"        # compression plus longue -> original
assert compresse("") == ""
assert compresse("aabbcc") == "aabbcc"    # "a2b2c2" fait la meme longueur -> original
assert compresse("aaaaaaaaaa") == "a10"
print("OK")

# %% [markdown]
# ## Exercice 6 -- Majuscule a chaque mot
#
# Ecris `titre(s)` qui met en majuscule la premiere lettre de chaque mot,
# **sans utiliser** `str.title()` ni `str.capitalize()`. Les mots sont separes
# par un seul espace.

# %%
def titre(s):
    # TODO : majuscule au debut de chaque mot, sans title()/capitalize()
    pass

# %%
# Test -- Exercice 6
assert titre("le chat noir dort") == "Le Chat Noir Dort"
assert titre("python") == "Python"
assert titre("") == ""
assert titre("deja Majuscule") == "Deja Majuscule"
print("OK")

# %% [markdown]
# ## Exercice 7 -- Supprimer les doublons en gardant l'ordre
#
# Ecris `sans_doublons(s)` qui retourne `s` avec les caracteres dupliques
# retires, en conservant la **premiere occurrence** et l'ordre d'origine.

# %%
def sans_doublons(s):
    # TODO : retourne s sans caracteres dupliques, ordre d'origine conserve
    pass

# %%
# Test -- Exercice 7
assert sans_doublons("mississippi") == "misp"
assert sans_doublons("") == ""
assert sans_doublons("aaaa") == "a"
assert sans_doublons("abcabc") == "abc"
assert sans_doublons("abcdef") == "abcdef"
print("OK")

# %% [markdown]
# ## Exercice 8 -- Plus longue sous-chaine sans repetition
#
# Ecris `plus_longue_sans_repetition(s)` qui retourne la **longueur** de la plus
# longue sous-chaine contigue de `s` ne contenant aucun caractere repete.
# (Classique d'entretien -- indice : fenetre glissante avec un set ou un dict.)

# %%
def plus_longue_sans_repetition(s):
    # TODO : longueur de la plus longue sous-chaine sans caractere repete
    pass

# %%
# Test -- Exercice 8
assert plus_longue_sans_repetition("abcabcbb") == 3   # "abc"
assert plus_longue_sans_repetition("bbbbb") == 1       # "b"
assert plus_longue_sans_repetition("pwwkew") == 3      # "wke"
assert plus_longue_sans_repetition("") == 0
assert plus_longue_sans_repetition("abcdef") == 6
print("OK")

# %% [markdown]
# ## Exercice 9 -- Grouper les anagrammes
#
# Ecris `groupe_anagrammes(mots)` qui prend une liste de mots et retourne une
# **liste de listes**, regroupant ensemble les mots qui sont anagrammes entre
# eux. L'ordre des groupes et l'ordre des mots dans chaque groupe n'ont pas
# d'importance pour le test (on compare des ensembles triés).

# %%
def groupe_anagrammes(mots):
    # TODO : retourne les mots regroupes par anagramme (liste de listes)
    pass

# %%
# Test -- Exercice 9
def _normalise(groupes):
    return sorted(sorted(g) for g in groupes)

resultat = groupe_anagrammes(["eat", "tea", "tan", "ate", "nat", "bat"])
attendu = [["eat", "tea", "ate"], ["tan", "nat"], ["bat"]]
assert _normalise(resultat) == _normalise(attendu)

assert _normalise(groupe_anagrammes([])) == []
assert _normalise(groupe_anagrammes(["abc"])) == [["abc"]]
print("OK")
