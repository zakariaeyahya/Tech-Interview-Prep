# %% [markdown]
# # Test technique Data Scientist / Machine Learning Engineer
# ## Notebook 1 - Python & Data Manipulation
#
# **Durée indicative : 45 minutes**
# **Niveau : Junior / Junior+**
#
# Ce notebook évalue les compétences Python, les structures de données, la manipulation de données avec Pandas et la compréhension de la complexité temporelle.
#
# Consignes :
# - Répondez directement dans les cellules Code sous chaque exercice.
# - Vous pouvez ajouter des cellules de brouillon si nécessaire.
# - Ne modifiez pas les énoncés.
# - Justifiez brièvement vos choix lorsque l'exercice le demande.
# - Les cas de test fournis sont indicatifs ; vous pouvez en ajouter d'autres.

# %% [markdown]
# ## Exercice 1 - Listes et list comprehensions
# **Temps conseillé : 4 minutes**
#
# On dispose d'une liste de montants de factures clients :
#
# `amounts = [120, 45, 300, 80, 220, 15, 500, 60]`
#
# Écrivez une fonction `filter_large_amounts(amounts, threshold)` qui retourne une nouvelle liste contenant uniquement les montants strictement supérieurs à `threshold`.
#
# Contraintes :
# - Utiliser une list comprehension.
# - Ne pas modifier la liste d'origine.
#
# Cas de test :
# - `filter_large_amounts([120, 45, 300], 100)` doit retourner `[120, 300]`.
# - `filter_large_amounts([10, 20, 30], 50)` doit retourner `[]`.
# - `filter_large_amounts([], 100)` doit retourner `[]`.

# %%
# Votre solution ici

# %% [markdown]
# ## Exercice 2 - Dictionnaires et manipulation de chaînes
# **Temps conseillé : 4 minutes**
#
# On souhaite normaliser des noms d'entreprises avant de les comparer.
#
# Écrivez une fonction `normalize_company_names(names)` qui prend une liste de chaînes de caractères et retourne un dictionnaire où :
# - la clé est le nom d'origine ;
# - la valeur est le nom normalisé.
#
# Règles de normalisation :
# - supprimer les espaces au début et à la fin ;
# - convertir en minuscules ;
# - remplacer les espaces multiples par un seul espace.
#
# Cas de test :
# - `normalize_company_names(["  Coface  ", "ACME   Corp", "Beta Ltd"])` doit retourner un dictionnaire contenant `"  Coface  ": "coface"` et `"ACME   Corp": "acme corp"`.
# - `normalize_company_names([])` doit retourner `{}`.

# %%
# Votre solution ici

# %% [markdown]
# ## Exercice 3 - Sets et détection de doublons
# **Temps conseillé : 4 minutes**
#
# On reçoit une liste d'identifiants de demandes de crédit. Certains identifiants peuvent apparaître plusieurs fois.
#
# Écrivez une fonction `find_duplicate_ids(request_ids)` qui retourne un set contenant les identifiants présents au moins deux fois.
#
# Contraintes :
# - Utiliser au moins un set.
# - La fonction doit fonctionner avec une liste vide.
#
# Cas de test :
# - `find_duplicate_ids(["R1", "R2", "R3", "R2", "R1"])` doit retourner `{"R1", "R2"}`.
# - `find_duplicate_ids(["R1", "R2", "R3"])` doit retourner `set()`.
# - `find_duplicate_ids([])` doit retourner `set()`.

# %%
# Votre solution ici

# %% [markdown]
# ## Exercice 4 - Counter
# **Temps conseillé : 4 minutes**
#
# On analyse les statuts de dossiers de recouvrement :
#
# `statuses = ["open", "closed", "open", "pending", "closed", "open"]`
#
# Écrivez une fonction `count_statuses(statuses)` qui retourne les fréquences de chaque statut sous forme de dictionnaire.
#
# Contraintes :
# - Utiliser `collections.Counter`.
# - Retourner un dictionnaire standard, pas directement un objet `Counter`.
#
# Cas de test :
# - `count_statuses(["open", "closed", "open"])` doit retourner `{"open": 2, "closed": 1}`.
# - `count_statuses([])` doit retourner `{}`.

# %%
# Votre solution ici

# %% [markdown]
# ## Exercice 5 - defaultdict et agrégation simple
# **Temps conseillé : 5 minutes**
#
# On dispose d'une liste de transactions sous la forme `(country, amount)` :
#
# `transactions = [("FR", 100), ("DE", 200), ("FR", 50), ("ES", 70), ("DE", 30)]`
#
# Écrivez une fonction `sum_amounts_by_country(transactions)` qui retourne un dictionnaire contenant le montant total par pays.
#
# Contraintes :
# - Utiliser `collections.defaultdict`.
# - Retourner un dictionnaire standard.
#
# Cas de test :
# - `sum_amounts_by_country([("FR", 100), ("FR", 50), ("DE", 200)])` doit retourner `{"FR": 150, "DE": 200}`.
# - `sum_amounts_by_country([])` doit retourner `{}`.

# %%
# Votre solution ici

# %% [markdown]
# ## Exercice 6 - Lambda et sorted avec key
# **Temps conseillé : 4 minutes**
#
# On souhaite trier des clients par score de risque décroissant, puis par nom croissant en cas d'égalité.
#
# Données d'exemple :
#
# `clients = [{"name": "Alpha", "risk_score": 0.72}, {"name": "Beta", "risk_score": 0.91}, {"name": "Gamma", "risk_score": 0.72}]`
#
# Écrivez une fonction `sort_clients_by_risk(clients)` qui retourne une nouvelle liste triée.
#
# Contraintes :
# - Utiliser `sorted`.
# - Utiliser une fonction `lambda` pour le paramètre `key`.
# - Ne pas modifier la liste d'origine.
#
# Cas de test :
# - Pour les données d'exemple, l'ordre attendu des noms est `Beta`, `Alpha`, `Gamma`.
# - `sort_clients_by_risk([])` doit retourner `[]`.

# %%
# Votre solution ici

# %% [markdown]
# ## Exercice 7 - Complexité temporelle
# **Temps conseillé : 4 minutes**
#
# On veut savoir si deux listes d'identifiants clients ont au moins un identifiant en commun.
#
# Écrivez une fonction `has_common_client(list_a, list_b)` qui retourne `True` si les deux listes ont au moins un élément commun, sinon `False`.
#
# Contraintes :
# - Proposer une solution plus efficace qu'une double boucle imbriquée.
# - Ajouter dans un commentaire la complexité temporelle attendue de votre solution.
#
# Cas de test :
# - `has_common_client([1, 2, 3], [4, 5, 3])` doit retourner `True`.
# - `has_common_client([1, 2], [3, 4])` doit retourner `False`.
# - `has_common_client([], [1, 2])` doit retourner `False`.

# %%
# Votre solution ici

# %% [markdown]
# ## Exercice 8 - Pandas groupby et agrégations
# **Temps conseillé : 6 minutes**
#
# On dispose du DataFrame suivant :
#
# ```python
# import pandas as pd
#
# df = pd.DataFrame({
#     "country": ["FR", "FR", "DE", "DE", "ES"],
#     "sector": ["Retail", "Tech", "Retail", "Tech", "Retail"],
#     "exposure": [1000, 2500, 1200, 3000, 800],
#     "defaulted": [0, 1, 0, 0, 1]
# })
# ```
#
# Écrivez une fonction `country_exposure_summary(df)` qui retourne un DataFrame avec, pour chaque pays :
# - l'exposition totale ;
# - l'exposition moyenne ;
# - le nombre de lignes ;
# - le taux de défaut moyen.
#
# Cas de test :
# - Pour `FR`, l'exposition totale doit être `3500`.
# - Pour `DE`, le taux de défaut moyen doit être `0.0`.
# - Le DataFrame résultat doit contenir une ligne par pays.

# %%
# Votre solution ici

# %% [markdown]
# ## Exercice 9 - Valeurs manquantes
# **Temps conseillé : 5 minutes**
#
# On dispose d'un DataFrame contenant des informations clients :
#
# ```python
# import pandas as pd
# import numpy as np
#
# df = pd.DataFrame({
#     "client_id": [1, 2, 3, 4],
#     "revenue": [100000, np.nan, 75000, np.nan],
#     "country": ["FR", "DE", None, "FR"],
#     "employees": [10, 50, np.nan, 20]
# })
# ```
#
# Écrivez une fonction `clean_client_data(df)` qui retourne une copie nettoyée du DataFrame selon les règles suivantes :
# - remplacer les valeurs manquantes de `revenue` par la médiane de `revenue` ;
# - remplacer les valeurs manquantes de `employees` par la moyenne de `employees` ;
# - remplacer les valeurs manquantes de `country` par `"Unknown"` ;
# - ne pas modifier le DataFrame d'origine.
#
# Cas de test :
# - Le résultat ne doit contenir aucune valeur manquante.
# - Le DataFrame d'origine doit encore contenir ses valeurs manquantes.
# - Les valeurs manquantes de `country` doivent être remplacées par `"Unknown"`.

# %%
# Votre solution ici

# %% [markdown]
# ## Exercice 10 - Pandas merge et analyse métier
# **Temps conseillé : 7 minutes**
#
# On dispose de deux DataFrames :
#
# ```python
# import pandas as pd
#
# clients = pd.DataFrame({
#     "client_id": [1, 2, 3, 4],
#     "country": ["FR", "DE", "FR", "ES"],
#     "sector": ["Retail", "Tech", "Retail", "Energy"]
# })
#
# invoices = pd.DataFrame({
#     "invoice_id": [101, 102, 103, 104, 105],
#     "client_id": [1, 1, 2, 3, 5],
#     "amount": [1000, 1500, 2000, 500, 700],
#     "paid": [1, 0, 1, 0, 1]
# })
# ```
#
# Écrivez une fonction `client_invoice_summary(clients, invoices)` qui :
# - fusionne les deux DataFrames afin de conserver toutes les factures ;
# - calcule, par `client_id`, le montant total facturé et le taux moyen de paiement ;
# - conserve les colonnes `country` et `sector` lorsque l'information client existe ;
# - retourne un DataFrame trié par montant total décroissant.
#
# Cas de test :
# - Le client `1` doit avoir un montant total facturé de `2500`.
# - Le client `5` doit être présent même s'il n'existe pas dans `clients`.
# - Le DataFrame résultat doit être trié par montant total décroissant.

# %%
# Votre solution ici
